# %%
#Import libraries
import os
import pandas as pd
import numpy as np

# %%
#Import all the csv in current folder and load in dictionary
initial_data=dict()
initial_buy=['IBM','MSFT','GOOG','AAPL','AMZN']
num_of_ticker=len(initial_buy)
initial_data={file[:-4]:pd.read_csv(file,usecols=['Date','Close','Adj Close']) for r,d,f in os.walk(os.getcwd()) for file in f if ".csv" in file and "USD_JPY_2018" not in file}

# %%
#This function calculates dividend for each share and append as a new column to dataframe
def calculate_dividend(row):
    close_ratio=row['Close'].shift().fillna(0)/row['Close'].fillna(0)
    adj_close_ratio=row['Adj Close'].shift().fillna(0)/row['Adj Close'].fillna(0)
    return abs((adj_close_ratio-close_ratio)*row['Close'])

# %%
#Add Dividend Column
for ticker,value in initial_data.items():
    value['Dividend']=calculate_dividend(initial_data[ticker])

# %%
#Convert to Dataframe and Add Portfolio related columns
share_price_df=pd.concat(initial_data,axis=1,keys=None)
share_price_df['Index','High_Tech_Index']=share_price_df.loc[:,(slice(None),'Close')].mean(axis=1)
for x in range(num_of_ticker):
    share_price_df['Portfolio','Share_'+str(x)+'_Name']=np.NaN
    share_price_df['Portfolio','Share_'+str(x)+'_Quantity']=np.NaN
#share_price_df['Portfolio','Cash']=5000000.00
portfolio_df=share_price_df['Portfolio'].copy()
share_price_df.drop(columns=['Portfolio'],inplace=True)

# %%
#This function will help divide cash in equal parts. One can pass Cash as first parameter and number of partitions you want as second parameter.
#Function will return a list of equal parts.
def split_int_equally(number, partitions):
    equal_partitions=list()
    quotient=number//partitions
    remainder=number%partitions
    if(number<partitions):
        raise ValueError('Number should always be greater or equal to partition')
    elif (remainder == 0):
        for i in range(partitions):
            equal_partitions.append(quotient)
    else:
        for i in range(partitions):
            if(i>= (partitions-remainder)):
                equal_partitions.append(quotient+1)
            else:
                equal_partitions.append(quotient)
    return equal_partitions

# %%
#This function calculates total dividend accumulated for the day
def total_dividend_for_the_day(price_of_the_day,portfolio_of_the_day, number_of_current_holdings):
    total_dividend=0
    price=price_of_the_day.copy()
    portfolio=portfolio_of_the_day.copy()
    for x in range(number_of_current_holdings):
        ticker=portfolio.loc['Share_'+str(x)+'_Name']
        quantity=portfolio.loc['Share_'+str(x)+'_Quantity']
        dividend=price.loc[ticker,'Dividend']
        total_dividend+=(quantity*dividend)
    return total_dividend

# %%
#This function will execute buy order for the day
def buy(price_of_the_day,portfolio_of_the_day,list_to_buy):
    price=price_of_the_day.copy()
    portfolio=portfolio_of_the_day.copy()
    new_cash=0.0
    for distributed_cash,ticker,index in zip(split_int_equally(portfolio['Cash'],len(list_to_buy)),list_to_buy,range(len(list_to_buy))):
        portfolio.loc[['Share_'+str(index)+'_Name','Share_'+str(index)+'_Quantity']]=[ticker,distributed_cash//price.loc[ticker,'Close']]
        new_cash+=distributed_cash%price.loc[ticker,'Close']
        #print(distributed_cash,ticker,index,new_cash)
    portfolio['Cash']=new_cash
    return portfolio

# %%
#This function will execute sell order for the day
def sell(price_of_the_day,portfolio_of_the_day):
    price=price_of_the_day.copy()
    portfolio=portfolio_of_the_day.copy()
    sell_cash=portfolio.loc['Cash']+total_dividend_for_the_day(price,portfolio,5)
    for index in range(num_of_ticker):
        quantity=portfolio.loc['Share_'+str(index)+'_Quantity']
        ticker=portfolio.loc['Share_'+str(index)+'_Name']
        sell_cash+=(quantity*price.loc[ticker,'Close'])
        portfolio.loc['Share_'+str(index)+'_Quantity']=0.0
        portfolio.loc['Share_'+str(index)+'_Name']=np.NaN
    portfolio.loc['Cash']=sell_cash
    return portfolio

# %%
#This function will return list of shares to buy depending upon what strategy you choose
def get_list_to_buy(currentrow,previousrow,strategy):
    if strategy=='buying low':
        return ((currentrow[:,'Adj Close']-previousrow[:,'Adj Close'])/previousrow[:,'Adj Close']).astype('float64').nsmallest().index.tolist()
    elif strategy=='buying high':
        return ((currentrow[:,'Adj Close']-previousrow[:,'Adj Close'])/previousrow[:,'Adj Close']).astype('float64').nlargest().index.tolist()  
    else:
        raise ValueError("Strategy value should be 'buying high' or 'buying low'")

# %%
#This function returns MTM until the day the paramter has been passsed
def MTM(price_of_the_day,portfolio_of_the_day):
    price=price_of_the_day.copy()
    portfolio=portfolio_of_the_day.copy()
    sell_cash=portfolio.loc['Cash']+total_dividend_for_the_day(price,portfolio,5)
    for index in range(num_of_ticker):
        quantity=portfolio.loc['Share_'+str(index)+'_Quantity']
        ticker=portfolio.loc['Share_'+str(index)+'_Name']
        sell_cash+=(quantity*price.loc[ticker,'Close'])
    return sell_cash

# %%
def portfolio_management_algorithm(initial_cash, initial_buy_list, rebalance_days, rebalance_strategy):
    portfolio_df[:]=np.NaN
    portfolio_df['Cash']=initial_cash
    portfolio_df['MTM']=0.0
    for i in range(len(share_price_df)):
        if i==0:
            ser=buy(share_price_df.loc[i],portfolio_df.loc[i],initial_buy_list)
            portfolio_df.loc[i]=ser
            print("Initial Buying is done. Row {0} in portfolio is updated".format(i))
        elif i%rebalance_days!=0:
            portfolio_df.loc[i]=portfolio_df.loc[i-1]
            portfolio_df.loc[i,'Cash']+=total_dividend_for_the_day(share_price_df.loc[i],portfolio_df.loc[i],len(initial_buy_list))
            print("No New Buying. Dividends have been added to cash. Row {0} in portfolio is updated".format(i))
        elif i%rebalance_days==0:
            portfolio_df.loc[i]=portfolio_df.loc[i-1]
            sell_ser=sell(share_price_df.loc[i],portfolio_df.loc[i])
            portfolio_df.loc[i]=sell_ser
            list_to_buy=get_list_to_buy(share_price_df.loc[i],share_price_df.loc[i-rebalance_days],rebalance_strategy)
            buy_ser=buy(share_price_df.loc[i],portfolio_df.loc[i],list_to_buy)
            portfolio_df.loc[i]=buy_ser
            print("{1} stocks have been bought . Row {0} in portfolio is updated".format(i,list_to_buy))
        portfolio_df.loc[i,'MTM']=MTM(share_price_df.loc[i],portfolio_df.loc[i])

# %%
portfolio_management_algorithm(5000000,initial_buy,5,'buying low')
# Out:
# Initial Buying is done. Row 0 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 1 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 2 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 3 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 4 in portfolio is updated
# ['AAPL', 'SAP', 'MSFT', 'FB', 'GOOG'] stocks have been bought . Row 5 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 6 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 7 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 8 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 9 in portfolio is updated
# ['FB', 'SAP', 'MSFT', 'GOOG', 'ORCL'] stocks have been bought . Row 10 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 11 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 12 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 13 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 14 in portfolio is updated
# ['AAPL', 'IBM', 'TSLA', 'MSFT', 'ORCL'] stocks have been bought . Row 15 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 16 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 17 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 18 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 19 in portfolio is updated
# ['AAPL', 'IBM', 'SAP', 'FB', 'ORCL'] stocks have been bought . Row 20 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 21 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 22 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 23 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 24 in portfolio is updated
# ['GOOG', 'SAP', 'IBM', 'MSFT', 'ORCL'] stocks have been bought . Row 25 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 26 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 27 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 28 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 29 in portfolio is updated
# ['TSLA', 'FB', 'SAP', 'NFLX', 'ORCL'] stocks have been bought . Row 30 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 31 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 32 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 33 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 34 in portfolio is updated
# ['IBM', 'SAP', 'FB', 'ORCL', 'MSFT'] stocks have been bought . Row 35 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 36 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 37 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 38 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 39 in portfolio is updated
# ['TSLA', 'GOOG', 'SAP', 'FB', 'ORCL'] stocks have been bought . Row 40 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 41 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 42 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 43 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 44 in portfolio is updated
# ['TSLA', 'AAPL', 'IBM', 'MSFT', 'FB'] stocks have been bought . Row 45 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 46 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 47 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 48 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 49 in portfolio is updated
# ['TSLA', 'MSFT', 'SAP', 'ORCL', 'FB'] stocks have been bought . Row 50 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 51 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 52 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 53 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 54 in portfolio is updated
# ['ORCL', 'FB', 'GOOG', 'AAPL', 'TSLA'] stocks have been bought . Row 55 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 56 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 57 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 58 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 59 in portfolio is updated
# ['TSLA', 'AMZN', 'NFLX', 'FB', 'GOOG'] stocks have been bought . Row 60 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 61 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 62 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 63 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 64 in portfolio is updated
# ['AMZN', 'GOOG', 'NFLX', 'ORCL', 'IBM'] stocks have been bought . Row 65 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 66 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 67 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 68 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 69 in portfolio is updated
# ['TSLA', 'AMZN', 'GOOG', 'SAP', 'ORCL'] stocks have been bought . Row 70 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 71 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 72 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 73 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 74 in portfolio is updated
# ['IBM', 'AAPL', 'TSLA', 'SAP', 'ORCL'] stocks have been bought . Row 75 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 76 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 77 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 78 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 79 in portfolio is updated
# ['NFLX', 'GOOG', 'AAPL', 'ORCL', 'MSFT'] stocks have been bought . Row 80 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 81 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 82 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 83 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 84 in portfolio is updated
# ['IBM', 'MSFT', 'TSLA', 'ORCL', 'AMZN'] stocks have been bought . Row 85 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 86 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 87 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 88 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 89 in portfolio is updated
# ['IBM', 'AMZN', 'SAP', 'NFLX', 'TSLA'] stocks have been bought . Row 90 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 91 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 92 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 93 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 94 in portfolio is updated
# ['TSLA', 'GOOG', 'FB', 'AMZN', 'AAPL'] stocks have been bought . Row 95 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 96 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 97 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 98 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 99 in portfolio is updated
# ['IBM', 'SAP', 'TSLA', 'GOOG', 'AAPL'] stocks have been bought . Row 100 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 101 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 102 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 103 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 104 in portfolio is updated
# ['IBM', 'SAP', 'ORCL', 'AAPL', 'NFLX'] stocks have been bought . Row 105 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 106 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 107 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 108 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 109 in portfolio is updated
# ['FB', 'GOOG', 'MSFT', 'AAPL', 'NFLX'] stocks have been bought . Row 110 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 111 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 112 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 113 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 114 in portfolio is updated
# ['ORCL', 'IBM', 'AAPL', 'SAP', 'MSFT'] stocks have been bought . Row 115 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 116 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 117 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 118 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 119 in portfolio is updated
# ['TSLA', 'ORCL', 'GOOG', 'IBM', 'AMZN'] stocks have been bought . Row 120 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 121 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 122 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 123 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 124 in portfolio is updated
# ['SAP', 'GOOG', 'FB', 'TSLA', 'IBM'] stocks have been bought . Row 125 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 126 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 127 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 128 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 129 in portfolio is updated
# ['TSLA', 'AAPL', 'AMZN', 'MSFT', 'GOOG'] stocks have been bought . Row 130 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 131 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 132 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 133 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 134 in portfolio is updated
# ['NFLX', 'IBM', 'TSLA', 'AAPL', 'SAP'] stocks have been bought . Row 135 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 136 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 137 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 138 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 139 in portfolio is updated
# ['TSLA', 'NFLX', 'SAP', 'AMZN', 'ORCL'] stocks have been bought . Row 140 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 141 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 142 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 143 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 144 in portfolio is updated
# ['FB', 'NFLX', 'AMZN', 'GOOG', 'ORCL'] stocks have been bought . Row 145 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 146 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 147 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 148 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 149 in portfolio is updated
# ['SAP', 'IBM', 'ORCL', 'GOOG', 'MSFT'] stocks have been bought . Row 150 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 151 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 152 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 153 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 154 in portfolio is updated
# ['TSLA', 'NFLX', 'FB', 'IBM', 'SAP'] stocks have been bought . Row 155 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 156 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 157 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 158 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 159 in portfolio is updated
# ['TSLA', 'FB', 'GOOG', 'MSFT', 'AMZN'] stocks have been bought . Row 160 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 161 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 162 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 163 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 164 in portfolio is updated
# ['TSLA', 'IBM', 'ORCL', 'FB', 'AAPL'] stocks have been bought . Row 165 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 166 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 167 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 168 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 169 in portfolio is updated
# ['TSLA', 'NFLX', 'SAP', 'FB', 'GOOG'] stocks have been bought . Row 170 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 171 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 172 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 173 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 174 in portfolio is updated
# ['FB', 'AAPL', 'GOOG', 'AMZN', 'IBM'] stocks have been bought . Row 175 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 176 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 177 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 178 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 179 in portfolio is updated
# ['AMZN', 'SAP', 'AAPL', 'NFLX', 'MSFT'] stocks have been bought . Row 180 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 181 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 182 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 183 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 184 in portfolio is updated
# ['GOOG', 'AAPL', 'IBM', 'MSFT', 'FB'] stocks have been bought . Row 185 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 186 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 187 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 188 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 189 in portfolio is updated
# ['TSLA', 'ORCL', 'FB', 'SAP', 'AMZN'] stocks have been bought . Row 190 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 191 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 192 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 193 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 194 in portfolio is updated
# ['NFLX', 'TSLA', 'GOOG', 'AMZN', 'SAP'] stocks have been bought . Row 195 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 196 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 197 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 198 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 199 in portfolio is updated
# ['IBM', 'ORCL', 'AAPL', 'SAP', 'GOOG'] stocks have been bought . Row 200 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 201 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 202 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 203 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 204 in portfolio is updated
# ['NFLX', 'SAP', 'AMZN', 'FB', 'MSFT'] stocks have been bought . Row 205 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 206 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 207 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 208 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 209 in portfolio is updated
# ['IBM', 'AMZN', 'NFLX', 'AAPL', 'GOOG'] stocks have been bought . Row 210 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 211 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 212 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 213 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 214 in portfolio is updated
# ['AAPL', 'FB', 'GOOG', 'SAP', 'ORCL'] stocks have been bought . Row 215 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 216 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 217 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 218 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 219 in portfolio is updated
# ['NFLX', 'AAPL', 'AMZN', 'MSFT', 'SAP'] stocks have been bought . Row 220 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 221 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 222 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 223 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 224 in portfolio is updated
# ['NFLX', 'FB', 'AAPL', 'AMZN', 'SAP'] stocks have been bought . Row 225 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 226 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 227 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 228 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 229 in portfolio is updated
# ['ORCL', 'TSLA', 'AAPL', 'SAP', 'IBM'] stocks have been bought . Row 230 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 231 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 232 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 233 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 234 in portfolio is updated
# ['NFLX', 'AAPL', 'MSFT', 'GOOG', 'ORCL'] stocks have been bought . Row 235 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 236 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 237 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 238 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 239 in portfolio is updated
# ['AMZN', 'AAPL', 'SAP', 'IBM', 'GOOG'] stocks have been bought . Row 240 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 241 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 242 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 243 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 244 in portfolio is updated
# ['AMZN', 'FB', 'TSLA', 'AAPL', 'NFLX'] stocks have been bought . Row 245 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 246 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 247 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 248 in portfolio is updated
# No New Buying. Dividends have been added to cash. Row 249 in portfolio is updated
# ['IBM', 'ORCL', 'MSFT', 'SAP', 'TSLA'] stocks have been bought . Row 250 in portfolio is updated

# %%
#Load USD to JPY conversion data
#Add Close column to portfolio 
#Wherever data for the date is not present, update with previous date data
USD_JPY={file[:-4]:pd.read_csv(file,usecols=['Date','Close']) for r,d,f in os.walk(os.getcwd()) for file in f if "USD_JPY_2018" in file}
portfolio_df['USD_JPY']=pd.merge(initial_data['IBM']['Date'],USD_JPY['USD_JPY_2018']['Close'],how='left',left_on=pd.to_datetime(initial_data['IBM']['Date']),right_on=pd.to_datetime(USD_JPY['USD_JPY_2018']['Date']))['Close']
while len(portfolio_df.loc[portfolio_df['USD_JPY'].isnull()])>0:
    portfolio_df.loc[:,'USD_JPY'].replace(to_replace=np.NaN,value=portfolio_df['USD_JPY'].shift(),inplace=True)
portfolio_df['MTM_JPY']=portfolio_df['MTM']*portfolio_df['USD_JPY']

# %%
share_price_df['Index','High_Tech_Index']=share_price_df.loc[:,(slice(None),'Close')].mean(axis=1)

# %%
#portfolio_df.columns = pd.MultiIndex.from_product([['Portfolio'],portfolio_df.columns])
#final_df=pd.concat([share_price_df,portfolio_df],axis=1,join='inner')
# Out:
#   Share_0_Name  Share_0_Quantity Share_1_Name  Share_1_Quantity Share_2_Name  \
# 0          IBM            6482.0         MSFT           11634.0         GOOG
# 1          IBM            6482.0         MSFT           11634.0         GOOG
# 2          IBM            6482.0         MSFT           11634.0         GOOG
# 3          IBM            6482.0         MSFT           11634.0         GOOG
# 4          IBM            6482.0         MSFT           11634.0         GOOG
#
#    Share_2_Quantity Share_3_Name  Share_3_Quantity Share_4_Name  \
# 0             938.0         AAPL            5805.0         AMZN
# 1             938.0         AAPL            5805.0         AMZN
# 2             938.0         AAPL            5805.0         AMZN
# 3             938.0         AAPL            5805.0         AMZN
# 4             938.0         AAPL            5805.0         AMZN
#
#    Share_4_Quantity         Cash           MTM  USD_JPY       MTM_JPY
# 0             841.0  1312.545517  5.000000e+06  112.511  5.625550e+08
# 1             841.0  1312.776643  5.061135e+06  112.751  5.706480e+08
# 2             841.0  1313.117963  5.103638e+06  113.054  5.769867e+08
# 3             841.0  1313.467721  5.164050e+06  113.054  5.838165e+08
# 4             841.0  1313.687237  5.187005e+06  112.648  5.843057e+08

# %%
#portfolio_df.head()
#final_df.head()
# Out:
#     Share_0_Name  Share_0_Quantity Share_1_Name  Share_1_Quantity  \
# 244         AMZN             691.0         AAPL            6655.0
# 245         AMZN             734.0           FB            8098.0
# 246         AMZN             734.0           FB            8098.0
# 247         AMZN             734.0           FB            8098.0
# 248         AMZN             734.0           FB            8098.0
# 249         AMZN             734.0           FB            8098.0
# 250          IBM            9459.0         ORCL           23814.0
#
#     Share_2_Name  Share_2_Quantity Share_3_Name  Share_3_Quantity  \
# 244          SAP           10905.0          IBM            9185.0
# 245         TSLA            3164.0         AAPL            6713.0
# 246         TSLA            3164.0         AAPL            6713.0
# 247         TSLA            3164.0         AAPL            6713.0
# 248         TSLA            3164.0         AAPL            6713.0
# 249         TSLA            3164.0         AAPL            6713.0
# 250         MSFT           10585.0          SAP           10800.0
#
#     Share_4_Name  Share_4_Quantity         Cash           MTM  USD_JPY
# 244         GOOG            1056.0  2626.384309  5.251380e+06  111.206
# 245         NFLX            4106.0  1163.616022  5.059337e+06  111.206
# 246         NFLX            4106.0  1163.680632  4.872863e+06  111.206
# 247         NFLX            4106.0  1163.726571  5.295794e+06  110.983
# 248         NFLX            4106.0  1163.851371  5.261191e+06  110.294
# 249         NFLX            4106.0  1163.949156  5.321285e+06  110.294
# 250         TSLA            3230.0   466.897650  5.376076e+06  110.294
